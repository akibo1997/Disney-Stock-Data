# %%
# %matplotlib notebook

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import datetime as dt
import calendar

disney_file = "Resources/DisneyHistoricalStockPriceData.csv"
disney_df = pd.read_csv(disney_file, encoding="ISO-8859-1")

# %%
disney_df.columns = ["date","open","high","low","close","volume"]
disney_df = disney_df[disney_df["open"] != "Open"]

# %%
disney_df.head()
# Out:
#          date    open    high     low   close    volume
# 1  2020-06-18  116.88  118.53  115.93  118.37   9562491
# 2  2020-06-17  118.64  119.23  117.14  117.65   8921557
# 3  2020-06-16  121.24   121.5  116.05  118.44  12951190
# 4  2020-06-15  112.08  118.12  111.71  117.08  14156378
# 5  2020-06-12  115.17     117  112.89  115.49  18361940

# %%
disney_df = disney_df[["date","close"]]
disney_df["date"] = pd.to_datetime(disney_df["date"])
disney_df["close"] = pd.to_numeric(disney_df["close"])
fixed_disney = disney_df.set_index("date")
fixed_disney.plot()

# %%
# Out:
# <img src="data:image/png;base64,..." width="638.888905813665">
