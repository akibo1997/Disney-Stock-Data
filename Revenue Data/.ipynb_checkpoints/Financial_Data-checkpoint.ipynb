# %%
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
from scipy.stats import linregress
import numpy as np

# %%
stock_path = "C:/Users/powde/Desktop/Disney-Stock-Data/Resources/Disney_Financial.csv"

# %%
purchase_data = pd.read_csv(stock_path, error_bad_lines=False)

# %%
#Changing the Index of the Stock Data
purchase_data = purchase_data.set_index('Fiscal Period')

# %%
#Rotating the Dataframe
purchase_data1=purchase_data.T

# %%
purchase_data1
# Out:
# Fiscal Period Revenue per Share EBITDA per Share EBIT per Share  \
# Jun90                     0.964            0.322          0.234
# Sep90                     1.082            0.329          0.227
# Dec90                     0.934            0.274           0.17
# Mar91                     0.922            0.238          0.125
# Jun91                     0.967            0.306          0.165
# ...                         ...              ...            ...
# Mar19                     9.709            5.376          4.837
# Jun19                     11.16            2.092          1.373
# Sep19                    10.518            1.634           0.92
# Dec19                    11.479            2.362          1.648
# Mar20                     9.917            1.519          0.785
#
# Fiscal Period Earnings per Share (Diluted) EPS without NRI  \
# Jun90                               0.0125          0.0125
# Sep90                             0.146982        0.146982
# Dec90                             0.009167        0.009167
# Mar91                             0.006667        0.006667
# Jun91                             0.008333        0.008333
# ...                                    ...             ...
# Mar19                                 3.55            3.53
# Jun19                                 0.97            0.79
# Sep19                                 0.58            0.43
# Dec19                                 1.16            1.17
# Mar20                                 0.25            0.26
#
# Fiscal Period Owner Earnings per Share (TTM) Free Cash Flow per Share  \
# Jun90                                  0.127                    0.028
# Sep90                                  0.561                    0.262
# Dec90                                  0.561                   -0.097
# Mar91                                  0.538                    0.083
# Jun91                                  0.669                    0.127
# ...                                      ...                      ...
# Mar19                                  8.531                     1.77
# Jun19                                  4.279                   -1.612
# Sep19                                   3.11                    0.225
# Dec19                                  2.845                    0.161
# Mar20                                  0.094                    1.052
#
# Fiscal Period Operating Cash Flow per Share Dividends per Share  \
# Jun90                                  0.16              0.0121
# Sep90                                 0.397              0.0121
# Dec90                                 0.065              0.0121
# Mar91                                 0.239              0.0121
# Jun91                                 0.276              0.0146
# ...                                     ...                 ...
# Mar19                                 2.547                   0
# Jun19                                -0.964                0.88
# Sep19                                 0.946                   0
# Dec19                                 0.897                0.88
# Mar20                                 1.738                   0
#
# Fiscal Period Book Value per Share  ... Price-to-Net-Net-Working-Capital  \
# Jun90                        2.094  ...                                0
# Sep90                        2.204  ...                                0
# Dec90                        2.197  ...                                0
# Mar91                         2.28  ...                                0
# Jun91                        2.355  ...                                0
# ...                            ...  ...                              ...
# Mar19                       50.499  ...                                0
# Jun19                       50.798  ...                                0
# Sep19                       49.903  ...                                0
# Dec19                        49.72  ...                                0
# Mar20                       49.784  ...                                0
#
# Fiscal Period Price-to-Graham-Number  \
# Jun90                           7.49
# Sep90                           2.49
# Dec90                            2.8
# Mar91                           3.24
# Jun91                           3.03
# ...                              ...
# Mar19                              0
# Jun19                              0
# Sep19                              0
# Dec19                              0
# Mar20                              0
#
# Fiscal Period Price-to-Intrinsic-Value-DCF (Earnings Based)  \
# Jun90                                                     0
# Sep90                                                     0
# Dec90                                                     0
# Mar91                                                     0
# Jun91                                                     0
# ...                                                     ...
# Mar19                                                  0.71
# Jun19                                                  1.02
# Sep19                                                  1.11
# Dec19                                                  1.38
# Mar20                                                  2.06
#
# Fiscal Period Price-to-Intrinsic-Value-DCF (FCF Based)  \
# Jun90                                                0
# Sep90                                                0
# Dec90                                                0
# Mar91                                                0
# Jun91                                                0
# ...                                                ...
# Mar19                                              1.4
# Jun19                                             4.02
# Sep19                                             8.85
# Dec19                                            17.79
# Mar20                                                0
#
# Fiscal Period Price-to-Earnings-Power-Value  \
# Jun90                                  6.64
# Sep90                                  1.69
# Dec90                                   3.4
# Mar91                                  9.01
# Jun91                                     0
# ...                                     ...
# Mar19                                  3.58
# Jun19                                  5.87
# Sep19                                  4.33
# Dec19                                  4.57
# Mar20                                  3.24
#
# Fiscal Period Price-to-Intrinsic-Value-Projected-FCF  \
# Jun90                                           5.17
# Sep90                                           2.68
# Dec90                                           3.29
# Mar91                                           3.46
# Jun91                                           2.87
# ...                                              ...
# Mar19                                           0.97
# Jun19                                           1.56
# Sep19                                           1.57
# Dec19                                           1.76
# Mar20                                           1.22
#
# Fiscal Period Price-to-Peter-Lynch-Fair-Value Price-to-Median-PB-Value  \
# Jun90                                       0                        0
# Sep90                                       0                        0
# Dec90                                       0                        0
# Mar91                                       0                        0
# Jun91                                       0                        0
# ...                                       ...                      ...
# Mar19                                    1.31                      0.7
# Jun19                                    1.97                     0.88
# Sep19                                    2.38                     0.83
# Dec19                                    3.44                     0.93
# Mar20                                       0                     0.62
#
# Fiscal Period Price-to-Median-PS-Value Price-to-Net-Cash
# Jun90                                0                 0
# Sep90                                0                 0
# Dec90                                0                 0
# Mar91                                0                 0
# Jun91                                0                 0
# ...                                ...               ...
# Mar19                             0.99                 0
# Jun19                             1.21                 0
# Sep19                             1.09                 0
# Dec19                             1.16                 0
# Mar20                             0.77                 0
#
# [120 rows x 224 columns]

# %%
#Creating New Dataframe With Important Variables
purchase_data2 = purchase_data1[["Highest Stock Price","Revenue", "Gross Profit"]]
purchase_data2
# Out:
# Fiscal Period Highest Stock Price Revenue Gross Profit
# Jun90                       10.77  1539.5        548.4
# Sep90                          11  1712.3          559
# Dec90                        8.67  1492.4        473.5
# Mar91                       10.41    1439        407.6
# Jun91                       10.08  1511.6        522.4
# ...                           ...     ...          ...
# Mar19                      115.25   14922         6546
# Jun19                      142.02   20245         7426
# Sep19                      146.39   19100         7278
# Dec19                      151.64   20858         7842
# Mar20                       148.2   18009         6091
#
# [120 rows x 3 columns]

# %%
#Checking the data types in the frame.
purchase_data2.dtypes
# Out:
# Fiscal Period
# Highest Stock Price    object
# Revenue                object
# Gross Profit           object
# dtype: object

# %%
#Creating a New .CSV to more easily manipulate data
purchase_data2.to_csv('file_name.csv', encoding='utf-8')
