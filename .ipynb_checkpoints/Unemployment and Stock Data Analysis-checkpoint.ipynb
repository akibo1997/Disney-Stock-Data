# %%
import pandas as pd
import matplotlib.pyplot as plt
import datetime as dt
from datetime import datetime
import numpy as np

file = "Resources/UNRATE.csv"

unemployment_rate_df = pd.read_csv(file, encoding = "ISO-8859-1")
unemployment_rate_df
# Out:
#            DATE  UNRATE
# 0    1948-01-01     3.4
# 1    1948-02-01     3.8
# 2    1948-03-01     4.0
# 3    1948-04-01     3.9
# 4    1948-05-01     3.5
# ..          ...     ...
# 864  2020-01-01     3.6
# 865  2020-02-01     3.5
# 866  2020-03-01     4.4
# 867  2020-04-01    14.7
# 868  2020-05-01    13.3
#
# [869 rows x 2 columns]

# %%
unemployment_rate_df['YearMonth'] = pd.to_datetime(unemployment_rate_df['DATE']).apply(lambda x: '{year}-{month}'.format(year=x.year, month=x.month))

# %%
unemployment_rate_df
# Out:
#            DATE  UNRATE YearMonth
# 0    1948-01-01     3.4    1948-1
# 1    1948-02-01     3.8    1948-2
# 2    1948-03-01     4.0    1948-3
# 3    1948-04-01     3.9    1948-4
# 4    1948-05-01     3.5    1948-5
# ..          ...     ...       ...
# 864  2020-01-01     3.6    2020-1
# 865  2020-02-01     3.5    2020-2
# 866  2020-03-01     4.4    2020-3
# 867  2020-04-01    14.7    2020-4
# 868  2020-05-01    13.3    2020-5
#
# [869 rows x 3 columns]

# %%
data_dict = {"YearMonth": unemployment_rate_df["YearMonth"], "Unemployment Rate": unemployment_rate_df["UNRATE"]}
new_unemployment_df = pd.DataFrame(data_dict)
new_unemployment_df
# Out:
#     YearMonth  Unemployment Rate
# 0      1948-1                3.4
# 1      1948-2                3.8
# 2      1948-3                4.0
# 3      1948-4                3.9
# 4      1948-5                3.5
# ..        ...                ...
# 864    2020-1                3.6
# 865    2020-2                3.5
# 866    2020-3                4.4
# 867    2020-4               14.7
# 868    2020-5               13.3
#
# [869 rows x 2 columns]

# %%
#unemployment_rate_df = unemployment_rate_df[(unemployment_rate_df['YearMonth'].dt.year > 1972)].drop(unemployment_rate_df.columns)

# %%
unemployment_rate_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 869 entries, 0 to 868
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   DATE       869 non-null    object
#  1   UNRATE     869 non-null    float64
#  2   YearMonth  869 non-null    object
# dtypes: float64(1), object(2)
# memory usage: 20.5+ KB

# %%
file2 = "Resources/DisneyHistoricalStockPriceData.csv"
stock_df = pd.read_csv(file2, encoding = "ISO-8859-1")
stock_df
# Out:
#       DIS - The Walt Disney Co Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0                         Date       Open       High        Low      Close
# 1                    6/18/2020     116.88     118.53     115.93     118.37
# 2                    6/17/2020     118.64     119.23     117.14     117.65
# 3                    6/16/2020     121.24      121.5     116.05     118.44
# 4                    6/15/2020     112.08     118.12     111.71     117.08
# ...                        ...        ...        ...        ...        ...
# 12529                 6/7/1972       1.69       1.69       1.69       1.69
# 12530                 6/6/1972       1.68       1.68       1.68       1.68
# 12531                 6/5/1972       1.68       1.68       1.68       1.68
# 12532                 6/2/1972       1.68       1.68       1.68       1.68
# 12533                 6/1/1972       1.68       1.68       1.68       1.68
#
#       Unnamed: 5
# 0         Volume
# 1        9562491
# 2        8921557
# 3       12951190
# 4       14156378
# ...          ...
# 12529          0
# 12530          0
# 12531          0
# 12532          0
# 12533          0
#
# [12534 rows x 6 columns]

# %%
stock_df.columns = ["date","open","high","low","close","volume"]

# %%
stock_df
# Out:
#             date    open    high     low   close    volume
# 0           Date    Open    High     Low   Close    Volume
# 1      6/18/2020  116.88  118.53  115.93  118.37   9562491
# 2      6/17/2020  118.64  119.23  117.14  117.65   8921557
# 3      6/16/2020  121.24   121.5  116.05  118.44  12951190
# 4      6/15/2020  112.08  118.12  111.71  117.08  14156378
# ...          ...     ...     ...     ...     ...       ...
# 12529   6/7/1972    1.69    1.69    1.69    1.69         0
# 12530   6/6/1972    1.68    1.68    1.68    1.68         0
# 12531   6/5/1972    1.68    1.68    1.68    1.68         0
# 12532   6/2/1972    1.68    1.68    1.68    1.68         0
# 12533   6/1/1972    1.68    1.68    1.68    1.68         0
#
# [12534 rows x 6 columns]

# %%
stock_df_2 = stock_df[stock_df["open"] != "Open"]

# %%
stock_df_2
# Out:
#             date    open    high     low   close    volume
# 1      6/18/2020  116.88  118.53  115.93  118.37   9562491
# 2      6/17/2020  118.64  119.23  117.14  117.65   8921557
# 3      6/16/2020  121.24   121.5  116.05  118.44  12951190
# 4      6/15/2020  112.08  118.12  111.71  117.08  14156378
# 5      6/12/2020  115.17     117  112.89  115.49  18361940
# ...          ...     ...     ...     ...     ...       ...
# 12529   6/7/1972    1.69    1.69    1.69    1.69         0
# 12530   6/6/1972    1.68    1.68    1.68    1.68         0
# 12531   6/5/1972    1.68    1.68    1.68    1.68         0
# 12532   6/2/1972    1.68    1.68    1.68    1.68         0
# 12533   6/1/1972    1.68    1.68    1.68    1.68         0
#
# [12533 rows x 6 columns]

# %%
stock_clean_df = stock_df_2[["date","close"]]

# %%
stock_clean_df
# Out:
#             date   close
# 1      6/18/2020  118.37
# 2      6/17/2020  117.65
# 3      6/16/2020  118.44
# 4      6/15/2020  117.08
# 5      6/12/2020  115.49
# ...          ...     ...
# 12529   6/7/1972    1.69
# 12530   6/6/1972    1.68
# 12531   6/5/1972    1.68
# 12532   6/2/1972    1.68
# 12533   6/1/1972    1.68
#
# [12533 rows x 2 columns]

# %%
stock_clean_df['close'] = stock_clean_df['close'].astype(float)
# Out:
# /Users/himanimanglik/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
stock_clean_df['YearMonth'] = pd.to_datetime(stock_clean_df['date']).apply(lambda x: '{year}-{month}'.format(year=x.year, month=x.month))
# Out:
# /Users/himanimanglik/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
stock_grouped_df = stock_clean_df.groupby('YearMonth').mean()

# %%
stock_grouped_df.sort_values(by='YearMonth', ascending=True)
# Out:
#                 close
# YearMonth
# 1972-10      1.630000
# 1972-11      1.746364
# 1972-12      2.005238
# 1972-6       1.683636
# 1972-7       1.722857
# ...               ...
# 2020-2     136.830000
# 2020-3     101.887727
# 2020-4     102.584545
# 2020-5     111.290476
# 2020-6     120.087857
#
# [577 rows x 1 columns]

# %%
stock_grouped_df
# Out:
#                 close
# YearMonth
# 1972-10      1.630000
# 1972-11      1.746364
# 1972-12      2.005238
# 1972-6       1.683636
# 1972-7       1.722857
# ...               ...
# 2020-2     136.830000
# 2020-3     101.887727
# 2020-4     102.584545
# 2020-5     111.290476
# 2020-6     120.087857
#
# [577 rows x 1 columns]

# %%
combined_data = new_unemployment_df.join(stock_grouped_df, on='YearMonth')

# %%
combined_data
# Out:
#     YearMonth  Unemployment Rate       close
# 0      1948-1                3.4         NaN
# 1      1948-2                3.8         NaN
# 2      1948-3                4.0         NaN
# 3      1948-4                3.9         NaN
# 4      1948-5                3.5         NaN
# ..        ...                ...         ...
# 864    2020-1                3.6  143.000435
# 865    2020-2                3.5  136.830000
# 866    2020-3                4.4  101.887727
# 867    2020-4               14.7  102.584545
# 868    2020-5               13.3  111.290476
#
# [869 rows x 3 columns]

# %%
combined_data.dropna(inplace = True)
combined_data.reset_index(drop=True)
# Out:
#     YearMonth  Unemployment Rate       close
# 0      1972-6                5.7    1.683636
# 1      1972-7                5.6    1.722857
# 2      1972-8                5.6    1.766087
# 3      1972-9                5.5    1.636190
# 4     1972-10                5.6    1.630000
# ..        ...                ...         ...
# 571    2020-1                3.6  143.000435
# 572    2020-2                3.5  136.830000
# 573    2020-3                4.4  101.887727
# 574    2020-4               14.7  102.584545
# 575    2020-5               13.3  111.290476
#
# [576 rows x 3 columns]

# %%
date_labels = []
for date_index in combined_data.index:
    if date_index%50 == 0:
        date_labels.append(combined_data["YearMonth"][date_index])
date_labels
# Out:
# ['1973-1',
#  '1977-3',
#  '1981-5',
#  '1985-7',
#  '1989-9',
#  '1993-11',
#  '1998-1',
#  '2002-3',
#  '2006-5',
#  '2010-7',
#  '2014-9',
#  '2018-11']

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax2 = ax.twinx()
ln_1 = ax.plot(np.arange(len(combined_data)),combined_data["Unemployment Rate"], color = "red", label = "Unemployment")
ln_2 = ax2.plot(np.arange(len(combined_data)),combined_data["close"], color = "green" , label = "Stock Price")
ax.set_xlabel("Year-Month")
ax.set_ylabel("Unemployment (%)")
ax2.set_ylabel("Stock Price ($)")
ax.set_xticks(np.arange(0,len(combined_data), 50))
ax.set_xticklabels(date_labels, rotation = 40)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
combined_data.plot()

# %%
plt.scatter(combined_data["Unemployment Rate"], combined_data["close"], marker="o", facecolors="red", edgecolors="black", alpha=0.75)

# %%
file3 = "Resources/ICSA.csv"
initial_claims_df= pd.read_csv(file3, encoding = "ISO-8859-1")

# %%
initial_claims_df
# Out:
#             DATE     ICSA
# 0     1967-01-07   208000
# 1     1967-01-14   207000
# 2     1967-01-21   217000
# 3     1967-01-28   204000
# 4     1967-02-04   216000
# ...          ...      ...
# 2785  2020-05-23  2123000
# 2786  2020-05-30  1897000
# 2787  2020-06-06  1566000
# 2788  2020-06-13  1540000
# 2789  2020-06-20  1480000
#
# [2790 rows x 2 columns]

# %%
initial_claims_df["YearMonth"] = pd.to_datetime(initial_claims_df["DATE"]).apply(lambda x: '{year}-{month}'.format(year=x.year, month=x.month))

# %%
claims_grouped_df = initial_claims_df.groupby("YearMonth").sum()

# %%
claims_grouped_df
# Out:
#                ICSA
# YearMonth
# 1967-1       836000
# 1967-10      867000
# 1967-11      825000
# 1967-12     1056000
# 1967-2       916000
# ...             ...
# 2020-2      1057000
# 2020-3     10667000
# 2020-4     20161000
# 2020-5     12329000
# 2020-6      4586000
#
# [642 rows x 1 columns]

# %%
combined_data_2 = claims_grouped_df.join(stock_grouped_df, on='YearMonth')

# %%
combined_data_2
# Out:
#                ICSA       close
# YearMonth
# 1967-1       836000         NaN
# 1967-10      867000         NaN
# 1967-11      825000         NaN
# 1967-12     1056000         NaN
# 1967-2       916000         NaN
# ...             ...         ...
# 2020-2      1057000  136.830000
# 2020-3     10667000  101.887727
# 2020-4     20161000  102.584545
# 2020-5     12329000  111.290476
# 2020-6      4586000  120.087857
#
# [642 rows x 2 columns]

# %%
combined_data_2.dropna(inplace = True)
combined_data_2
# Out:
#                ICSA       close
# YearMonth
# 1972-10     1004000    1.630000
# 1972-11     1003000    1.746364
# 1972-12     1212000    2.005238
# 1972-6      1093000    1.683636
# 1972-7      1488000    1.722857
# ...             ...         ...
# 2020-2      1057000  136.830000
# 2020-3     10667000  101.887727
# 2020-4     20161000  102.584545
# 2020-5     12329000  111.290476
# 2020-6      4586000  120.087857
#
# [577 rows x 2 columns]

# %%
date_labels = []
for date_index in combined_data_2.index:
    if date_index%50 == 0:
        date_labels.append(combined_data_2["YearMonth"][date_index])
date_labels
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-56-0d222f4b4a11> in <module>
#       1 date_labels = []
#       2 for date_index in combined_data_2.index:
# ----> 3     if date_index%50 == 0:
#       4         date_labels.append(combined_data_2["YearMonth"][date_index])
#       5 date_labels
#
# TypeError: not all arguments converted during string formatting

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax2 = ax.twinx()
ln_1 = ax.plot(np.arange(len(combined_data_2)),combined_data_2["ICSA"], color = "red", label = "Initial Claims")
ln_2 = ax2.plot(np.arange(len(combined_data_2)),combined_data_2["close"], color = "green" , label = "Stock Price")
ax.set_xlabel("Year-Month")
ax.set_ylabel("Initial Claims")
ax2.set_ylabel("Stock Price")
ax.set_xticks(np.arange(0,len(combined_data_2), 50))
ax.set_xticklabels(date_labels, rotation = 40)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>
